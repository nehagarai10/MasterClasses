# %% [markdown]
# Topic 1:  Fetching Financial Data

# %% [markdown]
# Fetching financial data from Yfinanace

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sn
import yfinance as yf
from datetime import date

# %%
Reliance = yf.Ticker("RELIANCE.NS")

# %%
Reliance.info
# Out:
# {'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 2535.5,
#  'open': 2528.9,
#  'dayLow': 2512.0,
#  'dayHigh': 2533.4,
#  'regularMarketPreviousClose': 2535.5,
#  'regularMarketOpen': 2528.9,
#  'regularMarketDayLow': 2512.0,
#  'regularMarketDayHigh': 2533.4,
#  'trailingPE': 28.798256,
#  'forwardPE': 35.0,
#  'volume': 3057360,
#  'regularMarketVolume': 3057360,
#  'averageVolume': 5281462,
#  'averageVolume10days': 4664834,
#  'averageDailyVolume10Day': 4664834,
#  'bid': 0.0,
#  'ask': 0.0,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 17014772989952,
#  'fiftyTwoWeekLow': 2180.0,
#  'fiftyTwoWeekHigh': 2755.0,
#  'fiftyDayAverage': 2458.07,
#  'twoHundredDayAverage': 2453.862,
#  'trailingAnnualDividendRate': 0.0,
#  'trailingAnnualDividendYield': 0.0,
#  'currency': 'INR',
#  'exchange': 'NSI',
#  'quoteType': 'EQUITY',
#  'symbol': 'RELIANCE.NS',
#  'underlyingSymbol': 'RELIANCE.NS',
#  'shortName': 'RELIANCE INDS',
#  'longName': 'Reliance Industries Limited',
# ...

# %% [markdown]
# get historical market data - OHLC

# %%
historical_data_reliance_eod = Reliance.history(period="1mo")

# %%
historical_data_reliance_eod
# Out:
#                                   Open         High          Low        Close
# Date
# 2023-05-23 00:00:00+05:30  2460.649902  2468.000000  2451.449951  2454.550049  \
# 2023-05-24 00:00:00+05:30  2445.899902  2464.000000  2433.449951  2440.250000
# 2023-05-25 00:00:00+05:30  2433.899902  2449.000000  2416.050049  2439.949951
# 2023-05-26 00:00:00+05:30  2458.000000  2509.000000  2450.750000  2506.500000
# 2023-05-29 00:00:00+05:30  2521.000000  2530.000000  2507.199951  2520.600098
# 2023-05-30 00:00:00+05:30  2520.600098  2537.699951  2514.350098  2519.949951
# 2023-05-31 00:00:00+05:30  2500.000000  2509.850098  2461.000000  2469.899902
# 2023-06-01 00:00:00+05:30  2480.149902  2484.899902  2458.000000  2463.250000
# 2023-06-02 00:00:00+05:30  2471.000000  2482.850098  2451.000000  2455.199951
# 2023-06-05 00:00:00+05:30  2467.199951  2483.750000  2458.449951  2477.250000
# 2023-06-06 00:00:00+05:30  2483.449951  2487.699951  2462.000000  2479.350098
# ...

# %%
rel = pd.DataFrame(Reliance.news)

# %%
rel.head(10)
# Out:
#                                    uuid
# 0  f3677a4f-be99-3c1f-a034-7be226577736  \
# 1  0f3bbe90-f17f-387b-9f59-9ca65013fae1
# 2  7899f189-fa66-3510-84d4-ccb1fad0187e
# 3  c36daea3-361c-3a1a-b56a-5f375e351c4e
# 4  0a034a74-74e6-3589-bb61-0fd407cbe8d2
# 5  a1cc0c3c-67ae-34f5-9e62-87fab3b688fc
# 6  4e2fc265-1b31-3890-a8cf-b187c7bae6e4
# 7  6db23549-6165-3fa9-86e5-8e49211e09da
#
#                                                title                publisher
# 0                           Horizon Therapeutics plc            GlobeNewswire  \
# 1  Announcement of the Release of Guidelines for ...              PR Newswire
# 2  EU governments converge on options to use Russ...                  Reuters
# 3  A Popular European Tourist Destination Just Ma...            TheStreet.com
# 4  The global strategy video game market is expec...            GlobeNewswire
# 5  CANADA STOCKS-TSX hits three-month low as ener...                  Reuters
# ...

# %%
 rel.drop("uuid", axis =1)
# Out:
#                                                title                publisher
# 0                           Horizon Therapeutics plc            GlobeNewswire  \
# 1  Announcement of the Release of Guidelines for ...              PR Newswire
# 2  EU governments converge on options to use Russ...                  Reuters
# 3  A Popular European Tourist Destination Just Ma...            TheStreet.com
# 4  The global strategy video game market is expec...            GlobeNewswire
# 5  CANADA STOCKS-TSX hits three-month low as ener...                  Reuters
# 6  Clean Energy’s Latest Problem Is Creaky Wind T...  The Wall Street Journal
# 7  Smirnoff ICE Hits the Road for Summer As Relau...              PR Newswire
#
#                                                 link  providerPublishTime
# 0  https://finance.yahoo.com/news/horizon-therape...           1687531320  \
# 1  https://finance.yahoo.com/news/announcement-re...           1687531260
# ...

# %%
import talib
import ta
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 import talib
#       2 import ta
#
# ModuleNotFoundError: No module named 'talib'

# %%
pip install talib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement talib (from versions: none)
# ERROR: No matching distribution found for talib

# %%
pip install ta
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for ta: filename=ta-0.10.2-py3-none-any.whl size=29098 sha256=13c67b8d55ca2c39fd680cfd3f63b17688bf7b41076e047dd39c172ecac00bb8
#   Stored in directory: c:\users\nehag\appdata\local\pip\cache\wheels\dd\a5\1b\04c9ab22e30c7d2c1810f0441356918ff458b493b4efaf5249
# Successfully built ta
# ...
# Note: you may need to restart the kernel to use updated packages.
